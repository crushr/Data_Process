# %%
import pandas as pd
pd = pd.read_csv('test.csv')
pd
# Out:
#                               img_id                   post_text label
# 0   62b31d36gw1ezuttozq82j20dw0kutax                    【每日美图】山居  real
# 1   a9570da6jw1exfh02r0d5j20p014n79n            新闻不能宣布人死亡，只有医生才能  real
# 2   62b31d36gw1ex8trzpizij20tr0h7whb             柯迪指挥官报告，我们已登上长城  real
# 3   62b31d36gw1ex8e8ntaqvj20qq0gxdhu              【每日美图】世界各地的清真寺  real
# 4   0067135Cjw1ex43zmge6jj30k50mqwif                        分享图片  real
# 5   62b31d36gw1ex2af01ed1j20qq0hvq6o  【每日美图】险：那些让人惊心动魄的道路，你会去走吗？  real
# 6   62b31d36gw1ezjq3p6d7mj20qq0lddkv                    #跨年#【欧洲】  real
# 7   62b31d36gw1ezjq1xivylj20qq0ha78v                    #跨年#【亚洲】  real
# 8   62b31d36gw1ezahmn8kb2j20qq0snjv5                 【马格南年度摄影大赏】  real
# 9   62b31d36gw1ez8ql608anj20qq0htwlm            【每日美图】2015旅行摄影大赏  real
# 10  62b31d36gw1eyttmx39wfj20qq0hu0uz                【每日美图】宝贝们的宝贝  real

# %%
import pandas as pd
pd = pd.read_csv('test.csv', header = None) # header = None 自动分配列名
pd
# Out:
#                                    0                           1      2
# 0                             img_id                   post_text  label
# 1   62b31d36gw1ezuttozq82j20dw0kutax                    【每日美图】山居   real
# 2   a9570da6jw1exfh02r0d5j20p014n79n            新闻不能宣布人死亡，只有医生才能   real
# 3   62b31d36gw1ex8trzpizij20tr0h7whb             柯迪指挥官报告，我们已登上长城   real
# 4   62b31d36gw1ex8e8ntaqvj20qq0gxdhu              【每日美图】世界各地的清真寺   real
# 5   0067135Cjw1ex43zmge6jj30k50mqwif                        分享图片   real
# 6   62b31d36gw1ex2af01ed1j20qq0hvq6o  【每日美图】险：那些让人惊心动魄的道路，你会去走吗？   real
# 7   62b31d36gw1ezjq3p6d7mj20qq0lddkv                    #跨年#【欧洲】   real
# 8   62b31d36gw1ezjq1xivylj20qq0ha78v                    #跨年#【亚洲】   real
# 9   62b31d36gw1ezahmn8kb2j20qq0snjv5                 【马格南年度摄影大赏】   real
# 10  62b31d36gw1ez8ql608anj20qq0htwlm            【每日美图】2015旅行摄影大赏   real
# 11  62b31d36gw1eyttmx39wfj20qq0hu0uz                【每日美图】宝贝们的宝贝   real

# %%
import pandas as pd
pd = pd.read_csv('test.csv', index_col=['label','img_id']) 
pd
# Out:
#                                                          post_text
# label img_id
# real  62b31d36gw1ezuttozq82j20dw0kutax                    【每日美图】山居
#       a9570da6jw1exfh02r0d5j20p014n79n            新闻不能宣布人死亡，只有医生才能
#       62b31d36gw1ex8trzpizij20tr0h7whb             柯迪指挥官报告，我们已登上长城
#       62b31d36gw1ex8e8ntaqvj20qq0gxdhu              【每日美图】世界各地的清真寺
#       0067135Cjw1ex43zmge6jj30k50mqwif                        分享图片
#       62b31d36gw1ex2af01ed1j20qq0hvq6o  【每日美图】险：那些让人惊心动魄的道路，你会去走吗？
#       62b31d36gw1ezjq3p6d7mj20qq0lddkv                    #跨年#【欧洲】
#       62b31d36gw1ezjq1xivylj20qq0ha78v                    #跨年#【亚洲】
#       62b31d36gw1ezahmn8kb2j20qq0snjv5                 【马格南年度摄影大赏】
#       62b31d36gw1ez8ql608anj20qq0htwlm            【每日美图】2015旅行摄影大赏
#       62b31d36gw1eyttmx39wfj20qq0hu0uz                【每日美图】宝贝们的宝贝

# %%
import pandas as pd
pd = pd.read_csv('test.csv', names=['1','2','3'], index_col = ['1','2','3']) # names 指定列名
pd
# Out:
#                                       1                           2
# 3
# label                            img_id                   post_text
# real   62b31d36gw1ezuttozq82j20dw0kutax                    【每日美图】山居
# real   a9570da6jw1exfh02r0d5j20p014n79n            新闻不能宣布人死亡，只有医生才能
# real   62b31d36gw1ex8trzpizij20tr0h7whb             柯迪指挥官报告，我们已登上长城
# real   62b31d36gw1ex8e8ntaqvj20qq0gxdhu              【每日美图】世界各地的清真寺
# real   0067135Cjw1ex43zmge6jj30k50mqwif                        分享图片
# real   62b31d36gw1ex2af01ed1j20qq0hvq6o  【每日美图】险：那些让人惊心动魄的道路，你会去走吗？
# real   62b31d36gw1ezjq3p6d7mj20qq0lddkv                    #跨年#【欧洲】
# real   62b31d36gw1ezjq1xivylj20qq0ha78v                    #跨年#【亚洲】
# real   62b31d36gw1ezahmn8kb2j20qq0snjv5                 【马格南年度摄影大赏】
# real   62b31d36gw1ez8ql608anj20qq0htwlm            【每日美图】2015旅行摄影大赏
# real   62b31d36gw1eyttmx39wfj20qq0hu0uz                【每日美图】宝贝们的宝贝
